# %% [markdown]
# This notebook builds the *full* [composite model](https://confluence.dhigroupinc.com/pages/viewpage.action?spaceKey=MT&title=Composite+Model) for Dice version 3.0.x, which includes the following submodels:
#
#   1. TfIdf similarity of job title/description to resume
#   2. Exact matching of Burning Glass skills by name, enriched with BG clusters and the BG-to-DHI skill crosswalk. See the [skills_model_feature_optimization notebook](./skills_model_feature_optimization.ipynb) for details.
#
# These are put into two [CompositeTransformer](https://bitbucket.org/dhigroupinc/dhi-match-datascience/src/master/src/dhi-dsmatch/dhi/dsmatch/sklearnmodeling/models/compositetransformer.py) pipeline transformers. The first pipeline that takes the ['job_title', 'job_description', 'resume'] columns is the TfIdf model, and the second pipeline takes the ['description_bg_parse', 'resume_bg_parse', 'job_title'] fields.
#
# This is the full model, which contains quantile data that can be purged after optimizing. Testing and optimizing is performed in [this notebook](./optimize_and_test_composite_model.ipynb).
#
# **Author:** Tom McTavish
#
# **Date:** November 18, 2021
#
# **Output:** models/dice/dice-composite_3.0.x_full.joblib
#
# This notebook takes about 30 minutes to run.

# %%
# %pip install -r requirements-inf.txt
# %pip install dhi-dsmatch[training]==1.1.0
# %pip install -e "git+ssh://git@bitbucket.org/dhigroupinc/dhi-match-datascience.git@MATCH-2343-remove-duplicate-skills-that-#egg=dhi-dsmatch[training]&subdirectory=src/dhi-dsmatch"

# %pip install -e "git+ssh://git@bitbucket.org/dhigroupinc/dhi-match-datascience.git@MATCH-2246-explore-bi-directional-crossw#egg=dhi-dsmatch[training]&subdirectory=src/dhi-dsmatch"
# %pip install -e "git+ssh://git@bitbucket.org/dhigroupinc/dhi-match-datascience.git@c485248#egg=dhi-dsmatch[training]&subdirectory=src/dhi-dsmatch"

# %pip install -e "git+ssh://git@bitbucket.org/dhigroupinc/dhi-match-datascience.git@feature/MATCH-2128-refactor-bg-skills-model-to-u#egg=dhi-dsmatch[training]&subdirectory=src/dhi-dsmatch"
# %pip install -e "git+ssh://git@bitbucket.org/dhigroupinc/dhi-match-datascience.git#egg=dhi-dsmatch[training]&subdirectory=src/dhi-dsmatch"
# Out:
# Looking in indexes: https://pypi.org/simple, https://dhigroupinc.jfrog.io/artifactory/api/pypi/taxonomy-python/simple, https://dhigroupinc.jfrog.io/artifactory/api/pypi/match-python/simple, https://dhigroupinc.jfrog.io/dhigroupinc/api/pypi/match-python-lib-prod-local/simple
# Collecting dhi-dsmatch==1.1.10
#   Downloading https://dhigroupinc.jfrog.io/dhigroupinc/api/pypi/match-python-lib-prod-local/dhi-dsmatch/1.1.10/dhi_dsmatch-1.1.10-py3-none-any.whl (110 kB)
#      |████████████████████████████████| 110 kB 29.3 MB/s
# Requirement already satisfied: joblib>=1.0.1 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.0.1)
# Requirement already satisfied: pandas>=1.2.3 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.2.5)
# Requirement already satisfied: scipy>=1.6.3 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.7.0)
# Requirement already satisfied: tqdm>=4.61.0 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (4.61.1)
# Requirement already satisfied: jsonpath-ng>=1.5.2 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.5.2)
# Requirement already satisfied: gensim>=4.0.1 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (4.0.1)
# Requirement already satisfied: numpy>=1.20.2 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.21.0)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (4.9.3)
# Requirement already satisfied: nltk>=3.6.2 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (3.6.2)
# Requirement already satisfied: scikit-learn>=1.0 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.0)
# Requirement already satisfied: contractions>=0.0.48 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (0.0.52)
# Requirement already satisfied: boto3==1.17.106 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.17.106)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from boto3==1.17.106->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.106 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from boto3==1.17.106->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.20.106)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from boto3==1.17.106->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (0.4.2)
# Requirement already satisfied: soupsieve>1.2 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from beautifulsoup4>=4.9.3->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (2.2.1)
# Requirement already satisfied: textsearch>=0.0.21 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from contractions>=0.0.48->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (0.0.21)
# Requirement already satisfied: smart-open>=1.8.1 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from gensim>=4.0.1->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (5.1.0)
# Requirement already satisfied: ply in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from jsonpath-ng>=1.5.2->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (3.11)
# Requirement already satisfied: six in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from jsonpath-ng>=1.5.2->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.16.0)
# Requirement already satisfied: decorator in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from jsonpath-ng>=1.5.2->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (5.0.9)
# Requirement already satisfied: regex in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from nltk>=3.6.2->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (2021.4.4)
# Requirement already satisfied: click in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from nltk>=3.6.2->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (7.1.2)
# Requirement already satisfied: pytz>=2017.3 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from pandas>=1.2.3->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from pandas>=1.2.3->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (2.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from scikit-learn>=1.0->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.106->boto3==1.17.106->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.26.4)
# Requirement already satisfied: pyahocorasick in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from textsearch>=0.0.21->contractions>=0.0.48->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (1.4.2)
# Requirement already satisfied: anyascii in /home/ec2-user/SageMaker/tom/.custom-miniconda/miniconda/envs/Python3.8/lib/python3.8/site-packages (from textsearch>=0.0.21->contractions>=0.0.48->dhi-dsmatch==1.1.10->-r requirements-inf.txt (line 2)) (0.2.0)
# Installing collected packages: dhi-dsmatch
#   Attempting uninstall: dhi-dsmatch
#     Found existing installation: dhi-dsmatch 1.1.12
#     Uninstalling dhi-dsmatch-1.1.12:
#       Successfully uninstalled dhi-dsmatch-1.1.12
# Successfully installed dhi-dsmatch-1.1.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from pathlib import Path

import yaml
import pandas as pd
import joblib
import boto3
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn import set_config
set_config(display='diagram')
from IPython.core.display import HTML

from dhi.dsmatch.sklearnmodeling.models.compositetransformer import CompositeTransformer
from dhi.dsmatch.sklearnmodeling.models.costfidftransformer import CosTfidfTransformer
from dhi.dsmatch.sklearnmodeling.models.bgleftoverlappingskillstransformer import BGLeftOverlappingSkillsTransformer, BGLeftOverlappingSkillsTransformerCore
from dhi.dsmatch.util.io import read_csv
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
pd.set_option('display.max_columns', 200)

# %% [markdown]
# # Load Parameters from config file

# %%
with open('config.yml', 'r') as f:
    params = yaml.load(f, Loader=yaml.FullLoader)
params
# Out:
# {'name': 'dice-composite',
#  'version': '3.0.13',
#  'cache_location': '/home/ec2-user/SageMaker/shared/data/dice/v2/dice-composite/cache',
#  'model_dir': '/home/ec2-user/SageMaker/shared/models/dice/',
#  'data_dir': '/home/ec2-user/SageMaker/shared/data/dice/',
#  'train_data': 's3://dev-matchology-datascience/data/dice/v2/dice_train_20211217.csv.zip',
#  'labeled_data': 's3://dev-matchology-datascience/data/dice/v2/dice_labeled_20211108_consensus.csv',
#  'skills_labeled_data': 's3://dev-matchology-datascience/data/dice/v2/dice_labeled_20211108_skills_consensus.csv',
#  'df_taxonomy_skills': 's3://dev-matchology-datascience/data/taxonomy/burning_glass_skills.csv',
#  'df_bgt_skills_crosswalk': 's3://dev-matchology-datascience/data/taxonomy/bgt_skills_crosswalk.csv',
#  'df_dhi_skills_crosswalk': 's3://dev-matchology-datascience/data/taxonomy/dhi_skills_crosswalk.csv',
#  'dhi_job_titles_to_related_skills': 's3://dev-matchology-datascience/data/taxonomy/dhi_job_titles_to_related_skills.txt',
#  's3_model_dir': 's3://dev-matchology-datascience/models/dice',
#  'gaussian_accuracy_threshold': 0.6,
#  'median_timing_threshold': 1000}

# %% [markdown]
# # Read in training data

# %%
# %%time
df = read_csv(params['train_data'])#, nrows=2_000)  # Uncomment nrows for quick iteration test/development.
df.head()
# Out:
# CPU times: user 1min 18s, sys: 7.76 s, total: 1min 26s
# Wall time: 1min 26s
#                             snapshot_id                        profile_id  \
# 0  4350cf17-f757-5c8a-b2e4-97a772b758a8  9e3468c4014bac5737dd0864543ab978
# 1  1b18511f-3339-44c4-92b4-8ac7418aa227  7c486ad56923319f8369f3cabf9778aa
# 2  421a2d27-06d8-5e86-8045-75df5bd32c41  9f8a9cbbfd69c11429f0576f77710129
# 3  68436bfa-c2c4-5849-b5e5-3252b97ae6af  744187a046aa197acad39dd325b43a07
# 4  22e4dfce-db6c-5a98-bb2f-87ad33ac40d0  b32f76fef50fc6d9fa874ef2c35fb47e
#
#    year  month  day                                     previous_title  \
# 0  2021      2   24   Network Engineer I:: Technical Solutions Analyst
# 1  2021     11   19                                                NaN
# 2  2021      4   20                                                NaN
# 3  2021      8   31  Field Service Technician:: Integration Special...
# 4  2020     12   28                                                NaN
#
#        current_title                                     profile_skills  \
# 0   Network Engineer                                                NaN
# 1  Android Developer  Software:: Android:: JSON:: RESTful:: Web serv...
# 2                NaN                                                NaN
# 3                NaN  Repair:: Network:: Technician:: Field service:...
# 4                NaN                                                NaN
#
#                                           job_skills  \
# 0  yaml:: amazon web services:: devops:: python::...
# 1               cocoa:: xcode 10.x:: ios sdk:: swift
# 2                                                NaN
# 3                               it support:: desktop
# 4                        .net core reactjs developer
#
#               desired_title                       job_title  \
# 0          Network Engineer                AWS Cloud DevOps
# 1         Android Developer    Mobile Application Developer
# 2       Sr. Project Manager              IT Project Manager
# 3  Field Service Technician           Deskside Support Lead
# 4           Stack Developer  Sr .Net Core ReactJs Developer
#
#                                      job_description  \
# 0  <!DOCTYPE html><html><head></head><body><p><st...
# 1  <!DOCTYPE html><html><head></head><body><p><sp...
# 2  <b>IT Project Manager Job Opening!</b> <br /> ...
# 3  <p><b><u>Job Title</u>:</b> <b>Deskside Suppor...
# 4  <B> Principal duties/Roles and responsibilitie...
#
#                                               resume  \
# 0   D. Email: ❖ Cell: ❖ LinkedIn: Technical Skill...
# 1  ﻿ Professional Summary: · Over 7 Years of tota...
# 2  ﻿ Anna Frisco, TX 75036 ♦ ♦ Linkedin: Professi...
# 3  ﻿ • • San Diego, CA Analytical and solutions-f...
# 4  ﻿ Email: Phone: Professional Summary: • 8+ yea...
#
#                      application_id  \
# 0  2c92808277b1615f0177d4f21a543063
# 1  c5de20d4d2d94d7c89110658f9c9fe9f
# 2  2c92808278eb4f3f0178ed929fa618d7
# 3  17a47e0c85ab4bcfbc84f21fda8c68ff
# 4  2c928082762f2e340176a9ac56953b3d
#
#                                 description_bg_parse  \
# 0  {"status": true, "status_code": "OK", "request...
# 1  {"status": true, "statusCode": "OK", "requestI...
# 2  {"status": true, "status_code": "OK", "request...
# 3  {"status": true, "status_code": "OK", "request...
# 4  {"status": true, "status_code": "OK", "request...
#
#                                      resume_bg_parse  \
# 0  {"status": true, "statusCode": "OK", "requestI...
# 1  {"status": true, "statusCode": "OK", "requestI...
# 2  {"status": true, "statusCode": "OK", "requestI...
# 3  {"status": true, "statusCode": "OK", "requestI...
# 4  {"status": true, "statusCode": "OK", "requestI...
#
#                                   job_data_bg_skills  \
# 0  ["AWS CloudFormation", "AngularJS", "Ansible",...
# 1  ["Cocoa", "Communication Skills", "Creativity"...
# 2  ["Agile Development", "Budgeting", "Business P...
# 3  ["Application Packaging", "Audio / Visual Know...
# 4  [".NET", "ASP.NET", "Active Server Pages (ASP)...
#
#                                resume_data_bg_skills
# 0  ["Ansible", "Border Gateway Protocol (BGP)", "...
# 1  ["Android Software Development Kit (SDK)", "An...
# 2  ["Account Adjustment", "Agile Project Manageme...
# 3  ["Application Support", "Building Effective Re...
# 4  [".NET", "AJAX", "API Management", "ASP.NET", ...

# %%
# This model does not need the following columns, so delete them now.
df.drop(['profile_id', 'previous_title', 'current_title', 'profile_skills', 'desired_title'], axis=1, inplace=True)

# %%
eval_cols = ['job_title', 'job_description', 'resume', 'description_bg_parse', 'resume_bg_parse']
# eval_cols = ['description_bg_parse', 'resume_bg_parse']

# %% [markdown]
# The Burning Glass models need the taxonomy mapping.

# %%
df_taxonomy_skills = read_csv(params['df_taxonomy_skills'])
df_taxonomy_skills = df_taxonomy_skills[['skillLabel', 'skillClusterLabel']]
df_taxonomy_skills.sort_values(by=['skillLabel'], inplace=True)
df_taxonomy_skills.reset_index(drop=True, inplace=True)
df_taxonomy_skills.fillna('', inplace=True)
df_taxonomy_skills.skillClusterLabel[df_taxonomy_skills.skillLabel==df_taxonomy_skills.skillClusterLabel] = ''

# %%
def dhiskillsexactmatch_ignorecase(row):
    if row.dhiSkillsExactMatch != '':
        return row.dhiSkillsExactMatch
    bgt_lower = row.bgtSkill.lower()
    for x in row.dhiSkills.split(';'):
        if (x.lower() == bgt_lower) and (x != row.bgtSkill):
            return x
    return ''

def remove_exact_in_skills(row):
    newlist = row.dhiSkills.copy()
    if isinstance(row.dhiSkillsExactMatch, str):
        if row.dhiSkillsExactMatch in row.dhiSkills:
            newlist.remove(row.dhiSkillsExactMatch)
    return newlist
    
df_bgt_skills_crosswalk = read_csv(params['df_bgt_skills_crosswalk'])
df_bgt_skills_crosswalk = df_bgt_skills_crosswalk[['bgtSkill', 'dhiSkillsExactMatch', 'dhiSkills']]
df_bgt_skills_crosswalk.fillna('', inplace=True)
df_bgt_skills_crosswalk['dhiSkillsExactMatch'] = df_bgt_skills_crosswalk.apply(dhiskillsexactmatch_ignorecase, axis=1)
df_bgt_skills_crosswalk['dhiSkills'] = df_bgt_skills_crosswalk['dhiSkills'].apply(lambda x: x.split(';'))
df_bgt_skills_crosswalk['dhiSkills'] = df_bgt_skills_crosswalk.apply(remove_exact_in_skills, axis=1)
df_bgt_skills_crosswalk['skill'] = df_bgt_skills_crosswalk.dhiSkillsExactMatch.values
df_bgt_skills_crosswalk['skill'][df_bgt_skills_crosswalk['skill'] == ''] = df_bgt_skills_crosswalk.bgtSkill
df_bgt_skills_crosswalk = df_bgt_skills_crosswalk[['bgtSkill', 'dhiSkills', 'skill']]

# %%
def bgtskillsexactmatch_ignorecase(row):
    if row.bgtSkillsExactMatch != '':
        return row.bgtSkillsExactMatch
    dhi_lower = row.dhiSkill.lower()
    for x in row.bgtSkills.split(';'):
        if (x.lower() == dhi_lower) and (x != row.dhiSkill):
            return x
    return ''

def remove_exact_in_skills(row):
    newlist = row.bgtSkills.copy()
    if isinstance(row.bgtSkillsExactMatch, str):
        if row.bgtSkillsExactMatch in row.bgtSkills:
            newlist.remove(row.bgtSkillsExactMatch)
    return newlist

df_dhi_skills_crosswalk = read_csv(params['df_dhi_skills_crosswalk'])
# df_dhi_skills_crosswalk = df_dhi_skills_crosswalk[['bgtSkill', 'dhiSkills']]
df_dhi_skills_crosswalk.fillna('', inplace=True)
df_dhi_skills_crosswalk['bgtSkillsExactMatch'] = df_dhi_skills_crosswalk.apply(bgtskillsexactmatch_ignorecase, axis=1)
df_dhi_skills_crosswalk['bgtSkills'] = df_dhi_skills_crosswalk['bgtSkills'].apply(lambda x: x.split(';'))
df_dhi_skills_crosswalk['bgtSkills'] = df_dhi_skills_crosswalk.apply(remove_exact_in_skills, axis=1)
df_dhi_skills_crosswalk = df_dhi_skills_crosswalk[['dhiSkill', 'dhiSkillAliases', 'bgtSkills']]

# %% [markdown]
# # Create and train the composite model
#
# This may take about 30 minutes to train the full dataset.

# %%
costfidf_tx = CosTfidfTransformer()
overlapping_skills_tx = BGLeftOverlappingSkillsTransformer(
        df_taxonomy_skills=df_taxonomy_skills,
        df_bgt_skills_crosswalk=df_bgt_skills_crosswalk,
        df_dhi_skills_crosswalk=df_dhi_skills_crosswalk)

# %%
ct_tx = CompositeTransformer([
        ('costfidf', costfidf_tx, ['job_title', 'job_description', 'resume']),
        ('overlapping_skills', overlapping_skills_tx, ['description_bg_parse', 'resume_bg_parse', 'job_title'])
    ], 
    instance_name=params['name'], instance_version=params['version'])

# %%
# %%time
ct_tx.fit_transform(df[eval_cols])
# Out:
# clean_for_stemming:   0%|          | 0/150 [00:00<?, ?it/s]
# stem:   0%|          | 0/150 [00:00<?, ?it/s]
# _get_cossim_diag_helper:   0%|          | 0/100 [00:00<?, ?it/s]
# _get_confidence_helper:   0%|          | 0/50 [00:00<?, ?it/s]
# loads:   0%|          | 0/150 [00:00<?, ?it/s]
# extract_canonical_skill_names:   0%|          | 0/150 [00:00<?, ?it/s]
# _get_rand_scores:   0%|          | 0/50 [00:00<?, ?it/s]
# _get_confidence_helper:   0%|          | 0/50 [00:00<?, ?it/s]
# _drop_row:   0%|          | 0/50 [00:00<?, ?it/s]
# CPU times: user 8min 59s, sys: 32.3 s, total: 9min 32s
# Wall time: 25min 2s
#       costfidf__score costfidf__qtile costfidf__confidence  \
# 0            0.051712        0.176472             0.345585
# 1            0.094521        0.454577             0.617729
# 2            0.156614        0.748753             0.868089
# 3            0.081254        0.370896             0.597574
# 4            0.178119        0.810799             0.915683
# ...               ...             ...                  ...
# 99995        0.141959        0.694449             0.996829
# 99996        0.105828        0.521731             0.870655
# 99997        0.027908        0.049423             0.157021
# 99998        0.058864        0.221364             0.486593
# 99999        0.095053        0.457648             0.835937
#
#       overlapping_skills__score overlapping_skills__qtile  \
# 0                      0.370016                  0.115344
# 1                      0.420799                  0.162078
# 2                      0.659337                  0.519725
# 3                      0.518037                  0.282519
# 4                      0.904752                  0.917659
# ...                         ...                       ...
# 99995                  0.984691                  0.984078
# 99996                  0.885445                  0.896888
# 99997                  0.343562                  0.095852
# 99998                  0.625727                  0.457692
# 99999                   0.64471                  0.492339
#
#       overlapping_skills__confidence  \
# 0                           0.301485
# 1                           0.360377
# 2                           0.772557
# 3                           0.520606
# 4                            0.73696
# ...                              ...
# 99995                       0.794255
# 99996                       0.585767
# 99997                       0.272635
# 99998                       0.572319
# 99999                       0.485868
#
#                              overlapping_skills__details  confidence  \
# 0                                    label  descripti...    0.323535
# 1                                     label  descript...    0.489053
# 2                                             label  ...    0.820323
# 3                                     label  descript...    0.559090
# 4                                   label  descriptio...    0.826321
# ...                                                  ...         ...
# 99995                                   label  descri...    0.895542
# 99996                                   label  descri...    0.728211
# 99997                                                ...    0.214828
# 99998                             label  description_...    0.529456
# 99999                                   label  descri...    0.660902
#
#       costfidf__confimprt overlapping_skills__confimprt  confidence_total  \
# 0                0.415683                      0.388256          0.803939
# 1                0.555756                      0.424486          0.980242
# 2                0.658821                      0.621513          1.280334
# 3                0.546614                      0.510199          1.056813
# 4                 0.67664                      0.607025          1.283665
# ...                   ...                           ...               ...
# 99995            0.705985                      0.630181          1.336165
# 99996            0.659793                      0.541187          1.200981
# 99997            0.280197                      0.369212          0.649409
# 99998            0.493251                      0.534939          1.028190
# 99999            0.646505                      0.492883          1.139388
#
#       costfidf__relative_weight overlapping_skills__relative_weight  \
# 0                      0.517058                            0.482942
# 1                      0.566958                            0.433042
# 2                      0.514569                            0.485431
# 3                      0.517229                            0.482771
# 4                      0.527115                            0.472885
# ...                         ...                                 ...
# 99995                  0.528366                            0.471634
# 99996                  0.549379                            0.450621
# 99997                  0.431465                            0.568535
# 99998                  0.479728                            0.520272
# 99999                  0.567414                            0.432586
#
#       costfidf__contribution overlapping_skills__contribution  \
# 0                   0.091246                         0.055704
# 1                   0.257726                         0.070187
# 2                   0.385285                         0.252291
# 3                   0.191838                         0.136392
# 4                   0.427385                         0.433947
# ...                      ...                              ...
# 99995               0.366923                         0.464124
# 99996               0.286628                         0.404157
# 99997               0.021324                         0.054495
# 99998               0.106195                         0.238125
# 99999               0.259676                         0.212979
#
#        composite_score     qtile  pred
# 0             0.146951  0.079727     1
# 1             0.327913  0.236688     2
# 2             0.637576  0.668248     3
# 3             0.328230  0.237129     2
# 4             0.861331  0.942829     5
# ...                ...       ...   ...
# 99995         0.831048  0.917752     5
# 99996         0.690785  0.749464     4
# 99997         0.075819  0.032281     1
# 99998         0.344319  0.253869     2
# 99999         0.472655  0.408476     3
#
# [100000 rows x 18 columns]

# %% [markdown]
# # Confirm that we can do a transform on a few rows

# %%
ct_tx.transform(df.loc[:4, eval_cols])
# Out:
#   costfidf__score costfidf__qtile costfidf__confidence  \
# 0        0.051712        0.176472             0.345585
# 1        0.094521        0.454577             0.617729
# 2        0.156614        0.748753             0.868089
# 3        0.081254        0.370896             0.597574
# 4        0.178119        0.810799             0.915683
#
#   overlapping_skills__score overlapping_skills__qtile  \
# 0                  0.370016                  0.115344
# 1                  0.420799                  0.162078
# 2                  0.659337                  0.519725
# 3                  0.518037                  0.282519
# 4                  0.904752                  0.917659
#
#   overlapping_skills__confidence  \
# 0                       0.301485
# 1                       0.360377
# 2                       0.772557
# 3                       0.520606
# 4                        0.73696
#
#                          overlapping_skills__details  confidence  \
# 0                                label  descripti...    0.323535
# 1                                 label  descript...    0.489053
# 2                                         label  ...    0.820323
# 3                                 label  descript...    0.559090
# 4                               label  descriptio...    0.826321
#
#   costfidf__confimprt overlapping_skills__confimprt  confidence_total  \
# 0            0.415683                      0.388256          0.803939
# 1            0.555756                      0.424486          0.980242
# 2            0.658821                      0.621513          1.280334
# 3            0.546614                      0.510199          1.056813
# 4             0.67664                      0.607025          1.283665
#
#   costfidf__relative_weight overlapping_skills__relative_weight  \
# 0                  0.517058                            0.482942
# 1                  0.566958                            0.433042
# 2                  0.514569                            0.485431
# 3                  0.517229                            0.482771
# 4                  0.527115                            0.472885
#
#   costfidf__contribution overlapping_skills__contribution  composite_score  \
# 0               0.091246                         0.055704         0.146951
# 1               0.257726                         0.070187         0.327913
# 2               0.385285                         0.252291         0.637576
# 3               0.191838                         0.136392         0.328230
# 4               0.427385                         0.433947         0.861331
#
#       qtile  pred
# 0  0.079727     1
# 1  0.236688     2
# 2  0.668248     3
# 3  0.237129     2
# 4  0.942829     5

# %% [markdown]
# # Confirm that we can do a transform on one row

# %%
idx = 6
X = ct_tx.transform(df.loc[idx:idx, eval_cols])
X
# Out:
#   costfidf__score costfidf__qtile costfidf__confidence  \
# 0        0.255996         0.93307             0.997938
#
#   overlapping_skills__score overlapping_skills__qtile  \
# 0                  0.818052                  0.806892
#
#   overlapping_skills__confidence  \
# 0                       0.680141
#
#                          overlapping_skills__details  confidence  \
# 0                                 label  descript...     0.83904
#
#   costfidf__confimprt overlapping_skills__confimprt  confidence_total  \
# 0            0.706378                      0.583156          1.289533
#
#   costfidf__relative_weight overlapping_skills__relative_weight  \
# 0                  0.547778                            0.452222
#
#   costfidf__contribution overlapping_skills__contribution  composite_score  \
# 0               0.511115                         0.364895          0.87601
#
#       qtile  pred
# 0  0.953899     5

# %% [markdown]
# # Confirm that `detailed_predict()` works

# %%
results = ct_tx.detailed_predict(df.loc[idx:idx, eval_cols].to_dict(orient='records'))
results
# Out:
# {'overall_name': 'dice-composite',
#  'overall_version': '3.0.13',
#  'composite_name': 'composite',
#  'composite_version': '2.0.1',
#  'composite_confidence': 0.8390396316186214,
#  'composite_rawscore': 0.8760095984015217,
#  'composite_score': 0.9538985173034121,
#  'overall_class': 5,
#  'composite_submodels': [{'domain': 'text',
#    'name': 'costfidf',
#    'version': '1.2',
#    'importance': 0.5,
#    'applied_weighting': 0.5477777500023132,
#    'confidence': 0.9979384527942814,
#    'score': 0.9330699492622891,
#    'explain': '{"rawscore": 0.25599567477902774}'},
#   {'domain': 'skills',
#    'name': 'overlapping_skills',
#    'version': '1.1.1',
#    'importance': 0.5,
#    'applied_weighting': 0.45222224999768684,
#    'confidence': 0.6801408104429614,
#    'score': 0.8068922769760196,
#    'explain': '{"details": {"label": {"0": "Information Technology", "1": "I.T. Administration", "2": "Technical support", "3": "Data", "4": "Database", "5": "Database administration", "6": "SQL Databases and Programming", "7": "System administration", "8": "Database Administration", "9": "System Design and Implementation", "10": "Industry-specific", "11": "Relational databases", "12": "Communication", "13": "Software development", "14": "Communication skills", "15": "Computer networking", "16": "General skills", "17": "Microsoft SQL Server", "18": "Operating systems", "19": "Systems Administration", "20": "Application development", "21": "Disaster recovery", "22": "Microsoft Windows Server", "23": "Operating Systems", "24": "Performance tuning", "25": "SQL", "26": "Servers", "27": "Troubleshooting", "28": "Writing", "29": "Active Directory", "30": "Data Modeling", "31": "Network Configuration", "32": "Network administration", "33": "Teamwork / Collaboration", "34": "Verbal / Oral Communication"}, "description_skills": {"0": 2.3046086099149354, "1": 1.508720486026021, "2": 1.508720486026021, "3": 1.2318651184158633, "4": 1.2318651184158633, "5": 1.2318651184158633, "6": 1.2318651184158633, "7": 1.2318651184158633, "8": 0.8710601787390263, "9": 0.8710601787390263, "10": 0.8710601787390263, "11": 0.8710601787390263, "12": 0.8710601787390263, "13": 0.8710601787390263, "14": 0.8710601787390263, "15": 0.8710601787390263, "16": 0.8710601787390263, "17": 0.8710601787390263, "18": 0.8710601787390263, "19": 0.8710601787390263, "20": 0.8710601787390263, "21": 0.8710601787390263, "22": 0.8710601787390263, "23": 0.8710601787390263, "24": 0.8710601787390263, "25": 0.8710601787390263, "26": 0.8710601787390263, "27": 0.8710601787390263, "28": 0.8710601787390263, "29": 0.8710601787390263, "30": 0.8710601787390263, "31": 0.8710601787390263, "32": 0.8710601787390263, "33": 0.8710601787390263, "34": 0.8710601787390263}, "resume_skills": {"0": 5.107758552314326, "1": 2.637635174608252, "2": 2.637635174608252, "3": 3.230430152703515, "4": 2.5253434165415625, "5": 2.4078204726700285, "6": 1.318817587304126, "7": 1.0768100509011718, "8": 1.7025861841047754, "9": 1.7025861841047754, "10": 1.5228393780840999, "11": 1.5228393780840999, "12": 1.318817587304126, "13": 1.318817587304126, "14": 1.0768100509011718, "15": 1.0768100509011718, "16": 1.0768100509011718, "17": 1.0768100509011718, "18": 1.0768100509011718, "19": 1.0768100509011718, "20": 0.7614196890420499, "21": 0.7614196890420499, "22": 0.7614196890420499, "23": 0.7614196890420499, "24": 0.7614196890420499, "25": 0.7614196890420499, "26": 0.7614196890420499, "27": 0.7614196890420499, "28": 0.7614196890420499, "29": 0.0, "30": 0.0, "31": 0.0, "32": 0.0, "33": 0.0, "34": 0.0}, "penalty": {"0": 6.107758552314326e-09, "1": 3.637635174608252e-09, "2": 3.637635174608252e-09, "3": 4.230430152703515e-09, "4": 3.525343416541563e-09, "5": 3.4078204726700283e-09, "6": 2.318817587304126e-09, "7": 0.15505506859150162, "8": 2.7025861841047756e-09, "9": 2.7025861841047756e-09, "10": 2.5228393780841e-09, "11": 2.5228393780841e-09, "12": 2.318817587304126e-09, "13": 2.318817587304126e-09, "14": 2.076810050901172e-09, "15": 2.076810050901172e-09, "16": 2.076810050901172e-09, "17": 2.076810050901172e-09, "18": 2.076810050901172e-09, "19": 2.076810050901172e-09, "20": 0.10964049045839606, "21": 0.10964049045839606, "22": 0.10964049045839606, "23": 0.10964049045839606, "24": 0.10964049045839606, "25": 0.10964049045839606, "26": 0.10964049045839606, "27": 0.10964049045839606, "28": 0.10964049045839606, "29": 0.8710601787390263, "30": 0.8710601787390263, "31": 0.8710601787390263, "32": 0.8710601787390263, "33": 0.8710601787390263, "34": 0.8710601787390263}}, "rawscore": 0.8180519825838283}'}],
#  'composite_explain': '{"top_matches": [{"job_skill": "Information Technology", "profile_skill": "Information Technology", "score": 1.0}, {"job_skill": "I.T. Administration", "profile_skill": "I.T. Administration", "score": 1.0}, {"job_skill": "Technical support", "profile_skill": "Technical support", "score": 1.0}, {"job_skill": "Data", "profile_skill": "Data", "score": 1.0}, {"job_skill": "Database", "profile_skill": "Database", "score": 1.0}]}',
#  'overall_score': 0.9538985173034121}

# %%
# import numpy as np
# rowcols = np.arange(1,6)
# model = ct_tx
# model.set_prediction_thresholds_from_labels(df_labeled.overall)
# df_labeled['pred'] = model.predict(df_labeled[eval_cols])
# df_xtab = labeled_xtab(df_labeled, pred_col='pred', labeled_col='overall', rownames=rowcols, colnames=rowcols)
# d_stats = aggregate_stats_from_xtab(df_xtab)
# print_aggregate_stats(d_stats)
# display(HTML(df_xtab.to_html()))

# %% [markdown]
# # Save the model locally, then upload to s3.

# %%
Path(params['model_dir']).mkdir(parents=True, exist_ok=True)
fname = f'{params["name"]}_{params["version"]}_full.joblib'
ct_tx.save_model(ct_tx, os.path.join(params['model_dir'], fname))

# %%
path = params['s3_model_dir'].split('s3://')[-1].split('/')
bucket = path[0]
key = '/'.join(path[1:]) + '/' + fname
print(f'Uploading: s3://{bucket}/{key}')
boto3.Session().resource('s3').Bucket(bucket).Object(key)\
    .upload_file(os.path.join(params['model_dir'], fname))
